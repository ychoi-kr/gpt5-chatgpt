# %% [markdown]
# <a href="https://colab.research.google.com/github/ychoi-kr/gpt5-chatgpt/blob/main/8_finetuning/4_evaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U datasets

# %%
from datasets import load_dataset

# 데이터셋 준비
dataset = load_dataset("ychoikr/Ani-Bench-JP-ko", split="test")
print(dataset[0])
# Out:
# README.md: 0.00B [00:00, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/10.2k [00:00<?, ?B/s]
# Generating test split:   0%|          | 0/100 [00:00<?, ? examples/s]
# {'문제': '주인공의 이름은 무엇입니까?', '답변': '카나메 마도카', '프로그램명': '마법소녀 마도카☆마기카'}

# %%
import json

# JSONL로 변환
with open("ani-bench-jp-ko.jsonl", "w", encoding="utf-8") as f:
    for entry in dataset:
        question_text = f"「{entry['프로그램명']}」에 관한 문제입니다. {entry['문제']}"
        new_entry = {"question": question_text, "ground_truth": entry["답변"]}
        f.write(json.dumps(new_entry, ensure_ascii=False) + "\n")
